# %%
import cv2
from deepface import DeepFace

img = cv2.imread('happyboy.jpg')

# %%
import matplotlib.pyplot as plt

# %%
plt.imshow(img)

# %%
plt.imshow(cv2.cvtColor(img, cv2.COLOR_BGR2RGB))

# %%
prediction = DeepFace.analyze(img)
# Out:
# Action: race: 100%|██████████| 4/4 [00:09<00:00,  2.46s/it]

# %%
prediction
# Out:
# [{'emotion': {'angry': 3.334601363868989e-08,
#    'disgust': 1.3450231077702308e-12,
#    'fear': 4.7672056170679983e-07,
#    'happy': 99.93184805728816,
#    'sad': 1.6537672591666527e-07,
#    'surprise': 0.00024216726002000805,
#    'neutral': 0.06790318066104584},
#   'dominant_emotion': 'happy',
#   'region': {'x': 203,
#    'y': 129,
#    'w': 178,
#    'h': 178,
#    'left_eye': (322, 202),
#    'right_eye': (262, 199)},
#   'face_confidence': 0.93,
#   'age': 43,
#   'gender': {'Woman': 11.119771748781204, 'Man': 88.88022303581238},
#   'dominant_gender': 'Man',
#   'race': {'asian': 19.213343466918882,
#    'indian': 13.846932512156071,
#    'black': 39.50182670376619,
#    'white': 3.089065472968277,
#    'middle eastern': 2.6441182367942617,
#    'latino hispanic': 21.704721057977803},
#   'dominant_race': 'black'}]

# %%
type(prediction)
# Out:
# list

# %%
prediction[0]['dominant_emotion']
# Out:
# 'happy'

# %%
faceCascade = cv2.CascadeClassifier(cv2.data.haarcascades + 'haarcascade_frontalface_default.xml')

# %%
gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
faces = faceCascade.detectMultiScale(gray, 1.1, 4)
for (x, y, w, h) in faces:
    cv2.rectangle(img, (x, y), (x + w, y + h), (0, 255, 0), 2)

# %%
plt.imshow(cv2.cvtColor(img, cv2.COLOR_BGR2RGB))

# %%
font = cv2.FONT_HERSHEY_SIMPLEX
cv2.putText(img, prediction[0]['dominant_emotion'], (50, 50), font, 3, (255, 0, 0), 2, cv2.LINE_4)
# Out:
# array([[[213, 186, 129],
#         [213, 186, 129],
#         [213, 186, 129],
#         ...,
#         [204, 179, 115],
#         [204, 179, 115],
#         [204, 179, 115]],
#
#        [[213, 186, 129],
#         [213, 186, 129],
#         [213, 186, 129],
#         ...,
#         [204, 179, 115],
#         [204, 179, 115],
#         [204, 179, 115]],
#
#        [[213, 186, 129],
#         [213, 186, 129],
#         [213, 186, 129],
#         ...,
#         [204, 179, 115],
#         [204, 179, 115],
#         [204, 179, 115]],
#
#        ...,
#
#        [[210, 184, 124],
#         [210, 184, 124],
#         [210, 184, 124],
#         ...,
#         [209, 183, 116],
#         [209, 183, 116],
#         [209, 183, 116]],
#
#        [[210, 184, 124],
#         [210, 184, 124],
#         [210, 184, 124],
#         ...,
#         [209, 183, 116],
#         [209, 183, 116],
#         [209, 183, 116]],
#
#        [[210, 184, 124],
#         [210, 184, 124],
#         [210, 184, 124],
# ...

# %%
plt.imshow(cv2.cvtColor(img, cv2.COLOR_BGR2RGB))

# %%
img = cv2.imread('sadwomen.jpg')

# %%
plt.imshow(cv2.cvtColor(img, cv2.COLOR_BGR2RGB))

# %%
prediction = DeepFace.analyze(img)
# Out:
# Action: race: 100%|██████████| 4/4 [00:12<00:00,  3.04s/it]

# %%
prediction
# Out:
# [{'emotion': {'angry': 0.3967738946839508,
#    'disgust': 8.279837895886391e-05,
#    'fear': 0.8718970751403019,
#    'happy': 0.00030468467681913806,
#    'sad': 97.37194164824137,
#    'surprise': 3.8069332179792815e-07,
#    'neutral': 1.3589985547362897},
#   'dominant_emotion': 'sad',
#   'region': {'x': 429,
#    'y': 71,
#    'w': 506,
#    'h': 506,
#    'left_eye': None,
#    'right_eye': None},
#   'face_confidence': 0.92,
#   'age': 28,
#   'gender': {'Woman': 99.20200705528259, 'Man': 0.797994714230299},
#   'dominant_gender': 'Woman',
#   'race': {'asian': 1.8159419298171997,
#    'indian': 1.640559360384941,
#    'black': 0.17690655076876283,
#    'white': 53.50865125656128,
#    'middle eastern': 19.886361062526703,
#    'latino hispanic': 22.97157794237137},
#   'dominant_race': 'white'}]

# %%
faceCascade = cv2.CascadeClassifier(cv2.data.haarcascades + 'haarcascade_frontalface_default.xml')

# %%
gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
faces = faceCascade.detectMultiScale(gray, 1.1, 4)
for (x, y, w, h) in faces:
    cv2.rectangle(img, (x, y), (x + w, y + h), (0, 255, 0), 2)

# %%
plt.imshow(cv2.cvtColor(img, cv2.COLOR_BGR2RGB))

# %%
font = cv2.FONT_HERSHEY_SIMPLEX
cv2.putText(img, prediction[0]['dominant_emotion'], (50, 50), font, 3, (255, 0, 0), 2, cv2.LINE_4)
# Out:
# array([[[125, 124, 126],
#         [126, 125, 127],
#         [126, 125, 127],
#         ...,
#         [124, 123, 125],
#         [123, 122, 124],
#         [123, 122, 124]],
#
#        [[126, 125, 127],
#         [126, 125, 127],
#         [126, 125, 127],
#         ...,
#         [125, 124, 126],
#         [124, 123, 125],
#         [123, 122, 124]],
#
#        [[125, 124, 126],
#         [125, 124, 126],
#         [125, 124, 126],
#         ...,
#         [126, 125, 127],
#         [124, 123, 125],
#         [123, 122, 124]],
#
#        ...,
#
#        [[ 34,  34,  34],
#         [ 34,  34,  34],
#         [ 34,  34,  34],
#         ...,
#         [ 11,  11,  11],
#         [ 18,  18,  18],
#         [ 20,  20,  20]],
#
#        [[ 33,  33,  33],
#         [ 33,  33,  33],
#         [ 33,  33,  33],
#         ...,
#         [  9,   9,   9],
#         [ 15,  15,  15],
#         [ 20,  20,  20]],
#
#        [[ 33,  33,  33],
#         [ 33,  33,  33],
#         [ 33,  33,  33],
# ...

# %%
plt.imshow(cv2.cvtColor(img, cv2.COLOR_BGR2RGB))
